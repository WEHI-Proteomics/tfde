# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
CONVERTED_DATABASE_NAME = '/Volumes/Samsung_T5/UPS2_DIA_180907/UPS2_DIA_180907.sqlite'

# %%
json_string = '[["convert_instrument_db", 5195.7], ["cluster_detect_ms1", 5584.2], ["recombine_frame_databases", 1867.1], ["feature_detect_ms1", 80.9], ["feature_region_ms1_peak_detect", 503.9], ["resolve_feature_list", 1003.9], ["feature_region_ms2_peak_detect", 7083.8], ["match_precursor_ms2_peaks", 128.6], ["correlate_peaks", 4544.9], ["deconvolve_ms2_spectra", 238.7], ["create_search_mgf", 173.6]]'

# %%
d = json.loads(json_string)

# %%
df = pd.DataFrame(d, columns=['step', 'time_secs'])

# %%
df
# Out:
#                               step  time_secs
# 0            convert_instrument_db     5195.7
# 1               cluster_detect_ms1     5584.2
# 2        recombine_frame_databases     1867.1
# 3               feature_detect_ms1       80.9
# 4   feature_region_ms1_peak_detect      503.9
# 5             resolve_feature_list     1003.9
# 6   feature_region_ms2_peak_detect     7083.8
# 7        match_precursor_ms2_peaks      128.6
# 8                  correlate_peaks     4544.9
# 9           deconvolve_ms2_spectra      238.7
# 10               create_search_mgf      173.6

# %%
df.time_secs.sum()/60/60
# Out:
# 7.334805555555556

# %%
fig, ax = plt.subplots()
fig.set_figheight(15)
fig.set_figwidth(15)
plt.pie(df.time_secs, labels=df.step, startangle=90, autopct='%.f%%')
plt.show()
