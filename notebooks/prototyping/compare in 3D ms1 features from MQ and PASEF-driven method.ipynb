# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt

# %%
# load the MQ features
mq_features_df = pd.read_pickle('/Users/darylwilding-mcbride/Downloads/mq-ms1-rt-3000-3060.pkl')
mq_features_df["hover"] = mq_features_df["mz"].map('{:,.4f} m/z'.format) + ', ' + mq_features_df["scan"].map('{} scan'.format) + ', ' + mq_features_df["rt"].map('RT {:.1f} secs'.format) + ', ' + mq_features_df["msms_scan_number"].map('msms scan number {}'.format)

# %%
evidence_df = pd.read_csv('/Users/darylwilding-mcbride/Downloads/maxquant_results/txt/evidence.txt', sep='\t')
evidence_df = evidence_df[(evidence_df['Retention time'] >= 3000) & (evidence_df['Retention time'] <= 3060)]
evidence_df['MS/MS scan number'] = evidence_df['MS/MS scan number'].apply(lambda x: int(x))

# %%
evidence_df[evidence_df['MS/MS scan number'] == 49607][['Sequence','MS/MS scan number']]
# Out:
#            Sequence  MS/MS scan number
# 4159  CLFSHVDFSGDGK              49607

# %%
mq_features_df = pd.merge(mq_features_df, evidence_df[['MS/MS scan number','Score']], how='left', left_on=['msms_scan_number'], right_on=['MS/MS scan number'])

# %%
mq_features_df = mq_features_df[mq_features_df['MS/MS scan number'].notnull() & mq_features_df['Score'].notnull()].copy()

# %%
mq_features_df.head()
# Out:
#            mz  charge  intensity  monoisotopic_mass        rt  scan  \
# 2   363.87617       3      12509         1088.60670  3029.586   825
# 14  417.23776       3      45793         1248.69150  3015.399   777
# 16  415.22893       3      19425         1242.66500  3041.400   795
# 21  422.26385       2     222860          842.51315  3035.494   678
# 24  426.25686       3     307840         1275.74880  3026.043   807
#
#     msms_scan_number                                              hover  \
# 2              20281  363.8762 m/z, 825 scan, RT 3029.6 secs, msms s...
# 14             32256  417.2378 m/z, 777 scan, RT 3015.4 secs, msms s...
# 16             31776  415.2289 m/z, 795 scan, RT 3041.4 secs, msms s...
# 21              6677  422.2638 m/z, 678 scan, RT 3035.5 secs, msms s...
# 24             34446  426.2569 m/z, 807 scan, RT 3026.0 secs, msms s...
#
#     MS/MS scan number   Score
# 2             20281.0  29.310
# 14            32256.0  29.310
# 16            31776.0  37.591
# 21             6677.0  49.058
# 24            34446.0  54.436

# %%
# load my features
my_features_df = pd.read_pickle('/Users/darylwilding-mcbride/Downloads/ms1_deduped_df.pkl')
my_features_df["hover"] = my_features_df["monoisotopic_mz"].map('{:,.4f} m/z'.format) + ', ' + my_features_df["scan_apex"].map('{:,.0f} scan'.format) + ', ' + my_features_df["rt_apex"].map('RT {:.1f} secs'.format) + ', ' + my_features_df["feature_id"].map('feature {}'.format)

# %%
my_features_df.head(2)
# Out:
#    candidate_phr_error  charge  \
# 0                  NaN       2
# 1           107.187047       2
#
#                                             envelope  intensity  \
# 0  ((673.3934, 2087210.00), (673.8940, 1552505.00...  4506011.0
# 1  ((561.2994, 2157318.00), (561.8004, 1519585.00...  4270685.0
#
#    mono_adjusted  monoisotopic_mz                                  ms2_frames  \
# 0          False       673.392282  [28128, 28129, 28132, 28136, 28137, 28208]
# 1          False       561.299369  [28138, 28140, 28152, 28185, 28196, 28330]
#
#                                      ms2_scan_ranges  original_phr  \
# 0  [(532, 557), (532, 557), (526, 551), (526, 551...      0.743818
# 1  [(609, 634), (609, 634), (608, 633), (607, 632...      0.704386
#
#    original_phr_error  ...  rt_curve_fit  rt_lower  rt_upper  scan_apex  \
# 0            0.027872  ...          True   3007.41   3029.48     541.96
# 1            0.170362  ...          True   3018.54   3043.09     619.70
#
#    scan_curve_fit  scan_lower  scan_upper  duplicates  feature_id  \
# 0            True      516.70      567.22           4           1
# 1            True      594.72      644.68           9           2
#
#                                                hover
# 0  673.3923 m/z, 542 scan, RT 3018.4 secs, feature 1
# 1  561.2994 m/z, 620 scan, RT 3030.8 secs, feature 2
#
# [2 rows x 22 columns]

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 3.5.0

# %%
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),  
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),  
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),  
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),  
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]

# %%
tableau20_py = tableau20.copy()

# %%
import plotly.plotly as py
import plotly.graph_objs as go

traces = []

trace = go.Scatter3d(
    x = my_features_df.monoisotopic_mz,
    y = my_features_df.rt_apex,
    z = my_features_df.scan_apex,
    mode = 'markers',
    marker = dict(
        size = 5,
        color = "rgb(255,128,128)",
        opacity = 0.7
    ),
    text = my_features_df.hover,
    hoverinfo = 'text',
    name = "PASEF-driven"
)
traces.append((trace))

trace = go.Scatter3d(
    x = mq_features_df.mz,
    y = mq_features_df.rt,
    z = mq_features_df.scan,
    mode = 'markers',
    marker = dict(
        size = 5,
        color = "rgb(128,100,255)",
        opacity = 0.7
    ),
    text = mq_features_df.hover,
    hoverinfo = 'text',
    name = "MaxQuant"
)
traces.append((trace))

data = traces
layout = go.Layout(
    autosize=False,
    width=1000,
    height=1000,
    title="Comparing ms1 features",
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=40
    ),
    scene = dict(
        xaxis = dict(
            title='m/z', autorange='reversed'),
        yaxis = dict(
            title='retention time'),
        zaxis = dict(
            title='scan'),
        aspectmode = "manual",
        aspectratio = dict( x = 50, y = 5, z = 5)
    )
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="2f099bd1-820b-4291-b397-528a112383ea" style="height: 1000px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2f099bd1-820b-4291-b397-528a112383ea", [{"hoverinfo": "text", "marker": {"color": "rgb(255,128,128)", "opacity": 0.7, "size": 5}, "mode": "markers", "name": "PASEF-driven", "text": ["673.3923 m/z, 542 scan, RT 3018.4 secs, feature 1", "561.2994 m/z, 620 scan, RT 3030.8 secs, feature 2", "615.8313 m/z, 598 scan, RT 3041.8 secs, feature 3", "725.8639 m/z, 540 scan, RT 3022.8 secs, feature 4", "591.6425 m/z, 613 scan, RT 3050.5 secs, feature 5", "670.3040 m/z, 710 scan, RT 3029.3 secs, feature 6", "832.8837 m/z, 480 scan, RT 3047.0 secs, feature 7", "504.2708 m/z, 714 scan, RT 3046.1 secs, feature 8", "615.8266 m/z, 616 scan, RT 3041.0 secs, feature 9", "615.5457 m/z, 698 scan, RT 3043.5 secs, feature 10", "687.6587 m/z, 672 scan, RT 3021.8 secs, feature 11", "442.2460 m/z, 761 scan, RT 3023.1 secs, feature 12", "536.2512 m/z, 629 scan, RT 3040.2 secs, feature 13", "832.3830 m/z, 444 scan, RT 3052.0 secs, feature 14", "616.8217 m/z, 636 scan, RT 3034.2 secs, feature 15", "539.7836 m/z, 651 scan, RT 3035.4 secs, feature 16", "616.8206 m/z, 592 scan, RT 3035.2 secs, feature 17", "594.8335 m/z, 611 scan, RT 3043.4 secs, feature 18", "525.9265 m/z, 729 scan, RT 3011.9 secs, feature 19", "639.9449 m/z, 558 scan, RT 3045.8 secs, feature 20", "568.2575 m/z, 729 scan, RT 3041.7 secs, feature 21", "644.3518 m/z, 554 scan, RT 3037.5 secs, feature 22", "552.7829 m/z, 643 scan, RT 3047.2 secs, feature 23", "522.7537 m/z, 688 scan, RT 3042.2 secs, feature 24", "529.3152 m/z, 646 scan, RT 3016.7 secs, feature 25", "594.8280 m/z, 618 scan, RT 3043.4 secs, feature 26", "616.8249 m/z, 601 scan, RT 3035.9 secs, feature 27", "657.8553 m/z, 571 scan, RT 3033.5 secs, feature 28", "673.3837 m/z, 539 scan, RT 3019.3 secs, feature 29", "585.2722 m/z, 666 scan, RT 3047.5 secs, feature 30", "646.3106 m/z, 549 scan, RT 3016.1 secs, feature 31", "646.3136 m/z, 604 scan, RT 3036.3 secs, feature 32", "600.3020 m/z, 703 scan, RT 3045.7 secs, feature 33", "725.8615 m/z, 490 scan, RT 3022.4 secs, feature 34", "929.0762 m/z, 539 scan, RT 3026.1 secs, feature 35", "499.9883 m/z, 718 scan, RT 3033.2 secs, feature 36", "463.2599 m/z, 717 scan, RT 3034.8 secs, feature 37", "588.2880 m/z, 596 scan, RT 3041.8 secs, feature 38", "688.3629 m/z, 540 scan, RT 3049.9 secs, feature 39", "518.7774 m/z, 669 scan, RT 3023.4 secs, feature 40", "639.9453 m/z, 593 scan, RT 3045.7 secs, feature 41", "644.3482 m/z, 558 scan, RT 3037.4 secs, feature 42", "523.2562 m/z, 684 scan, RT 3042.4 secs, feature 43", "550.3028 m/z, 661 scan, RT 3028.1 secs, feature 44", "561.2953 m/z, 620 scan, RT 3030.8 secs, feature 45", "538.2814 m/z, 698 scan, RT 3026.6 secs, feature 46", "548.7766 m/z, 655 scan, RT 3025.5 secs, feature 47", "543.6085 m/z, 719 scan, RT 3032.4 secs, feature 48", "565.2949 m/z, 613 scan, RT 3011.1 secs, feature 49", "476.2472 m/z, 694 scan, RT 3030.0 secs, feature 50", "479.2901 m/z, 666 scan, RT 3042.7 secs, feature 51", "628.3080 m/z, 571 scan, RT 3026.8 secs, feature 52", "822.3797 m/z, 453 scan, RT 3034.2 secs, feature 53", "419.7252 m/z, 764 scan, RT 3037.7 secs, feature 54", "526.2594 m/z, 774 scan, RT 3019.4 secs, feature 55", "464.9036 m/z, 733 scan, RT 3036.9 secs, feature 56", "413.2346 m/z, 734 scan, RT 3014.8 secs, feature 57", "767.3757 m/z, 487 scan, RT 3027.3 secs, feature 58", "538.2892 m/z, 703 scan, RT 3026.8 secs, feature 59", "713.3587 m/z, 491 scan, RT 3038.7 secs, feature 60", "548.5985 m/z, 677 scan, RT 3034.5 secs, feature 61", "500.7365 m/z, 683 scan, RT 3031.3 secs, feature 62", "736.6850 m/z, 530 scan, RT 3038.1 secs, feature 63", "463.2564 m/z, 718 scan, RT 3034.2 secs, feature 64", "801.8856 m/z, 449 scan, RT 3047.1 secs, feature 65", "699.8159 m/z, 550 scan, RT 30 ...
