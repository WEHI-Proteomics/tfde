# %%
import pandas as pd
from os.path import expanduser
import matplotlib.pyplot as plt
import json

# %%
experiment_name = 'P3856'
run_name = 'P3856_YHE211_1_Slot1-1_1_5104'
precursor_definition_method = 'pasef'

# %%
BASE_DIR = '{}/P3856-results-cs-true-fmdw-true-2021-04-24-19-58-32'.format(expanduser('~'))

FEATURES_DIR = '{}/features-{}'.format(BASE_DIR, precursor_definition_method)
FEATURES_NAME = '{}/exp-{}-run-{}-features-{}.pkl'.format(FEATURES_DIR, experiment_name, run_name, precursor_definition_method)
FEATURES_DEDUP_NAME = '{}/exp-{}-run-{}-features-{}-dedup.pkl'.format(FEATURES_DIR, experiment_name, run_name, precursor_definition_method)

# %%
df = pd.read_pickle(FEATURES_NAME)['features_df']

# %%
df[df.precursor_cuboid_id == 32394]
# Out:
#         mz_apex_without_saturation_correction  \
# 120451                             748.379393
# 120452                             745.867365
# 120453                             746.837997
# 120454                             747.631236
# 120455                             746.916850
#
#         mz_apex_with_saturation_correction    mz_lower    mz_upper  scan_apex  \
# 120451                          748.378665  748.355558  748.403229      571.0
# 120452                          745.868441  745.843610  745.891121      578.0
# 120453                          746.841290  746.814210  746.861783      597.0
# 120454                          747.634351  747.607425  747.655048      583.0
# 120455                          746.912237  746.893061  746.940639      567.0
#
#         scan_lower  scan_upper      rt_apex     rt_lower     rt_upper  ...  \
# 120451         551         611  2020.393600  2012.985108  2023.569211  ...
# 120452         565         613  2020.922863  2016.159890  2024.097713  ...
# 120453         567         613  2019.335875  2016.688869  2022.510341  ...
# 120454         554         599  2025.156912  2012.455167  2028.860792  ...
# 120455         538         582  2019.335875  2016.159890  2023.569211  ...
#
#         monoisotopic_mass  feature_intensity  \
# 120451        1494.742778              56470
# 120452        1489.722329              29103
# 120453        1491.668028              14772
# 120454        2986.508299                791
# 120455        1491.809922               9212
#
#                                                  envelope isotope_count  \
# 120451  [[748.3793933956638, 100726.0], [748.868799809...             4
# 120452  [[745.8673652852324, 74365.0], [746.3834276896...             4
# 120453  [[746.8379967021538, 29833.0], [747.3388667164...             4
# 120454  [[747.6312363036939, 1051.0], [747.87692536326...             5
# 120455  [[746.9168496599716, 20489.0], [747.4086729140...             4
#
#        deconvolution_score precursor_cuboid_id  \
# 120451          645.122814               32394
# 120452          521.527534               32394
# 120453          434.212163               32394
# 120454          356.763942               32394
# 120455          300.070817               32394
#
#                                           fragment_ions_l  \
# 120451  [{"singly_protonated_mass": 220.149, "neutral_...
# 120452  [{"singly_protonated_mass": 220.149, "neutral_...
# 120453  [{"singly_protonated_mass": 220.149, "neutral_...
# 120454  [{"singly_protonated_mass": 220.149, "neutral_...
# 120455  [{"singly_protonated_mass": 220.149, "neutral_...
#
#                                       fmdw_before_after_d  feature_id  \
# 120451  {'before_fmdw': [{'singly_protonated_mass': 22...     3239401
# 120452  {'before_fmdw': [{'singly_protonated_mass': 22...     3239402
# 120453  {'before_fmdw': [{'singly_protonated_mass': 22...     3239403
# 120454  {'before_fmdw': [{'singly_protonated_mass': 22...     3239404
# 120455  {'before_fmdw': [{'singly_protonated_mass': 22...     3239405
#
#                              run_name
# 120451  P3856_YHE211_1_Slot1-1_1_5104
# 120452  P3856_YHE211_1_Slot1-1_1_5104
# 120453  P3856_YHE211_1_Slot1-1_1_5104
# 120454  P3856_YHE211_1_Slot1-1_1_5104
# 120455  P3856_YHE211_1_Slot1-1_1_5104
#
# [5 rows x 28 columns]

# %%
features_df = pd.read_pickle(FEATURES_DEDUP_NAME)['features_df']

# %%
print('{} features'.format(len(features_df)))
# Out:
# 101898 features

# %%
mq_features_df = pd.read_pickle('/home/daryl/MQ-analysis-of-P3856/combined/P3856_YHE211_1_Slot1-1_1_5104-dwm.pkl')
mq_features_df['feature_id'] = mq_features_df.index.values.tolist()

# %%
print('{} MQ features'.format(len(mq_features_df)))
# Out:
# 18437 MQ features

# %% [markdown]
# #### browsing for a feature by attribute range

# %% [raw]
# df = features_df[(features_df.monoisotopic_mz > 1017) & (features_df.monoisotopic_mz < 1017.1) & (features_df.rt_apex > 2150) & (features_df.rt_apex < 2200)]
# df

# %% [raw]
# feature = features_df.loc[60604]

# %% [markdown]
# #### selecting a feature by feature_id

# %% [raw]
# feature = features_df[(features_df.feature_id == 3698001)].iloc[0]
# print('precursor id: {}'.format(feature.precursor_cuboid_id))

# %% [markdown]
# #### selecting a feature by precursor

# %%
features_df[(features_df.precursor_cuboid_id == 32394)]
# Out:
#         mz_apex_without_saturation_correction  \
# 120451                             748.379393
# 120452                             745.867365
# 120455                             746.916850
# 120454                             747.631236
#
#         mz_apex_with_saturation_correction    mz_lower    mz_upper  scan_apex  \
# 120451                          748.378665  748.355558  748.403229      571.0
# 120452                          745.868441  745.843610  745.891121      578.0
# 120455                          746.912237  746.893061  746.940639      567.0
# 120454                          747.634351  747.607425  747.655048      583.0
#
#         scan_lower  scan_upper      rt_apex     rt_lower     rt_upper  ...  \
# 120451         551         611  2020.393600  2012.985108  2023.569211  ...
# 120452         565         613  2020.922863  2016.159890  2024.097713  ...
# 120455         538         582  2019.335875  2016.159890  2023.569211  ...
# 120454         554         599  2025.156912  2012.455167  2028.860792  ...
#
#         monoisotopic_mass  feature_intensity  \
# 120451        1494.742778              56470
# 120452        1489.722329              29103
# 120455        1491.809922               9212
# 120454        2986.508299                791
#
#                                                  envelope isotope_count  \
# 120451  [[748.3793933956638, 100726.0], [748.868799809...             4
# 120452  [[745.8673652852324, 74365.0], [746.3834276896...             4
# 120455  [[746.9168496599716, 20489.0], [747.4086729140...             4
# 120454  [[747.6312363036939, 1051.0], [747.87692536326...             5
#
#        deconvolution_score precursor_cuboid_id  \
# 120451          645.122814               32394
# 120452          521.527534               32394
# 120455          300.070817               32394
# 120454          356.763942               32394
#
#                                           fragment_ions_l  \
# 120451  [{"singly_protonated_mass": 220.149, "neutral_...
# 120452  [{"singly_protonated_mass": 220.149, "neutral_...
# 120455  [{"singly_protonated_mass": 220.149, "neutral_...
# 120454  [{"singly_protonated_mass": 220.149, "neutral_...
#
#                                       fmdw_before_after_d  feature_id  \
# 120451  {'before_fmdw': [{'singly_protonated_mass': 22...     3239401
# 120452  {'before_fmdw': [{'singly_protonated_mass': 22...     3239402
# 120455  {'before_fmdw': [{'singly_protonated_mass': 22...     3239405
# 120454  {'before_fmdw': [{'singly_protonated_mass': 22...     3239404
#
#                              run_name
# 120451  P3856_YHE211_1_Slot1-1_1_5104
# 120452  P3856_YHE211_1_Slot1-1_1_5104
# 120455  P3856_YHE211_1_Slot1-1_1_5104
# 120454  P3856_YHE211_1_Slot1-1_1_5104
#
# [4 rows x 28 columns]

# %%
feature = features_df.loc[120454]

# %% [markdown]
# #### display the feature's attributes

# %%
feature
# Out:
# mz_apex_without_saturation_correction                                                     747.631
# mz_apex_with_saturation_correction                                                        747.634
# mz_lower                                                                                  747.607
# mz_upper                                                                                  747.655
# scan_apex                                                                                     583
# scan_lower                                                                                    554
# scan_upper                                                                                    599
# rt_apex                                                                                   2025.16
# rt_lower                                                                                  2012.46
# rt_upper                                                                                  2028.86
# mono_intensity_without_saturation_correction                                                  791
# mono_intensity_with_saturation_correction                                                     791
# mono_intensity_adjustment_outcome                                      monoisotopic_not_saturated
# isotopic_peaks                                  [{'mz': 747.6312363036939, 'mz_lower': 747.607...
# scan_df                                         [{'scan': 540, 'intensity': 42, 'filtered_inte...
# rt_df                                           [{'frame_id': 18032, 'retention_time_secs': 20...
# monoisotopic_mz                                                                           747.634
# charge                                                                                          4
# monoisotopic_mass                                                                         2986.51
# feature_intensity                                                                             791
# envelope                                        [[747.6312363036939, 1051.0], [747.87692536326...
# isotope_count                                                                                   5
# deconvolution_score                                                                       356.764
# precursor_cuboid_id                                                                         32394
# fragment_ions_l                                 [{"singly_protonated_mass": 220.149, "neutral_...
# fmdw_before_after_d                             {'before_fmdw': [{'singly_protonated_mass': 22...
# feature_id                                                                                3239404
# run_name                                                            P3856_YHE211_1_Slot1-1_1_5104
# Name: 120454, dtype: object

# %% [markdown]
# #### browsing for an MQ feature

# %% [raw]
# df = mq_features_df[(mq_features_df.monoisotopic_mz > 790.5) & (mq_features_df.monoisotopic_mz < 791) & (mq_features_df.charge == 2) & (mq_features_df.rt_apex > 1830) & (mq_features_df.rt_apex < 1850)]
# df

# %% [raw]
# feature_mq = df.loc[5173]

# %% [markdown]
# #### selecting an MQ feature by feature_id

# %% [raw]
# feature_mq = mq_features_df[(mq_features_df.feature_id == 235)].iloc[0]

# %% [markdown]
# #### selecting an MQ feature by index

# %%
mq_index_for_precursor = 22460  # from the notebook 'MaxQuant APL index from precursor id'
feature_mq = mq_features_df[(mq_features_df.mq_index == mq_index_for_precursor)].iloc[0]

# %% [markdown]
# #### display the feature's attributes

# %%
feature_mq
# Out:
# monoisotopic_mass                                              2987.49
# charge                                                               4
# monoisotopic_mz                                                747.879
# intensity                                                        53956
# scan_apex                                                          570
# rt_apex                                                           2022
# raw_file                                 P3856_YHE211_1_Slot1-1_1_5104
# mq_index                                                         22460
# ms2_peaks            [{'mz': 122.03192, 'intensity': 12}, {'mz': 21...
# feature_id                                                       17606
# Name: 17606, dtype: object

# %% [markdown]
# #### compare the feature attributes

# %%
print('\t\tmine\t\t\tmq')
print('mono m/z\t{}\t\t{}'.format(round(feature.monoisotopic_mz,4), round(feature_mq.monoisotopic_mz,4)))
print('charge\t\t{}\t\t\t{}'.format(feature.charge, feature_mq.charge))
print('RT\t\t{}\t\t\t{}'.format(round(feature.rt_apex,2), round(feature_mq.rt_apex,2)))
print('scan\t\t{}\t\t\t{}'.format(round(feature.scan_apex,2), round(feature_mq.scan_apex,2)))
# Out:
# 		mine			mq
# mono m/z	747.6344		747.8793
# charge		4			4
# RT		2025.16			2022.0
# scan		583.0			570

# %% [markdown]
# #### plot the fragment spectra

# %%
fragment_ions_df = pd.DataFrame(json.loads(feature.fragment_ions_l))
fragment_ions_df['normalised_intensity'] = fragment_ions_df.intensity / fragment_ions_df.intensity.max()

# %%
fragment_ions_mq_df = pd.DataFrame(feature_mq.ms2_peaks)
fragment_ions_mq_df['normalised_intensity'] = fragment_ions_mq_df.intensity / fragment_ions_mq_df.intensity.max()

# %%
f, ax = plt.subplots()
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

# plot the raw data
markerline, stemlines, baseline = ax.stem(fragment_ions_df.singly_protonated_mass, fragment_ions_df.normalised_intensity, markerfmt=" ", use_line_collection=True, label='mine')
plt.setp(markerline, 'color', 'tab:green')
plt.setp(stemlines, 'color', 'tab:green')
plt.setp(baseline, 'color', 'tab:gray')

# plot the filtered data
markerline, stemlines, baseline = ax.stem(fragment_ions_mq_df.mz, -fragment_ions_mq_df.normalised_intensity, markerfmt=" ", use_line_collection=True, label='MaxQuant')
plt.setp(markerline, 'color', 'tab:purple')
plt.setp(stemlines, 'color', 'tab:purple')
plt.setp(baseline, 'color', 'tab:gray')

plt.xlabel('neutral mass (Da)')
plt.ylabel('normalised intensity')
f.set_figheight(8)
f.set_figwidth(15)

plt.margins(0.06)
plt.legend(loc='best')
plt.title('')
plt.show()

# %%
f, ax = plt.subplots()
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

# plot the raw data
markerline, stemlines, baseline = ax.stem(fragment_ions_df.singly_protonated_mass, fragment_ions_df.normalised_intensity, markerfmt=" ", use_line_collection=True, label='mine')
plt.setp(markerline, 'color', 'tab:green')
plt.setp(stemlines, 'color', 'tab:green')
plt.setp(baseline, 'color', 'tab:gray')

# plot the filtered data
markerline, stemlines, baseline = ax.stem(fragment_ions_mq_df.mz, -fragment_ions_mq_df.normalised_intensity, markerfmt=" ", use_line_collection=True, label='MaxQuant')
plt.setp(markerline, 'color', 'tab:purple')
plt.setp(stemlines, 'color', 'tab:purple')
plt.setp(baseline, 'color', 'tab:gray')

plt.xlabel('neutral mass (Da)')
plt.ylabel('normalised intensity')
f.set_figheight(8)
f.set_figwidth(15)

# ax.set_xlim((1500,1700))

plt.margins(0.06)
plt.legend(loc='best')
plt.title('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7a00693fa6d4> in <module>
# ----> 1 f, ax = plt.subplots()
#       2 colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']
#       3
#       4 # plot the raw data
#       5 markerline, stemlines, baseline = ax.stem(fragment_ions_df.singly_protonated_mass, fragment_ions_df.normalised_intensity, markerfmt=" ", use_line_collection=True, label='mine')
#
# NameError: name 'plt' is not defined

# %%
fragment_ions_df[fragment_ions_df.normalised_intensity > 0.1]
# Out:
#      singly_protonated_mass  neutral_mass  intensity  normalised_intensity
# 30                 568.2954      567.2881     1765.0              0.119378
# 46                 673.3189      672.3116     1503.0              0.101657
# 57                 772.3879      771.3807     2150.0              0.145418
# 71                 885.4670      884.4597     2819.0              0.190666
# 91                1148.5800     1147.5727     4277.0              0.289280
# 97                1715.8707     1714.8635    10934.0              0.739533
# 99                1786.9077     1785.9004     4924.0              0.333040
# 100               2033.0492     2032.0420    14785.0              1.000000

# %%
fragment_ions_mq_df[fragment_ions_mq_df.normalised_intensity > 0.1]
# Out:
#              mz  intensity  normalised_intensity
# 70    885.46804        421              0.111523
# 78    984.49502        656              0.173775
# 96   1148.57950        657              0.174040
# 143  1715.86930       1567              0.415099
# 146  1749.89660       2223              0.588874
# 148  1786.90750        734              0.194437
# 150  1862.97650        606              0.160530
# 155  2032.00870       1629              0.431523
# 157  2034.05520       3775              1.000000
