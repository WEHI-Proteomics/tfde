# %%
from skimage import io, img_as_float
from matplotlib import pyplot as plt
import numpy as np

# %%
img = io.imread('/Users/darylwilding-mcbride/Downloads/yolo-train-rt-1000-4200-denoised-7-may-tile-33-overlay/frame-10007-tile-33-mz-700-718.png')

# %%
plt.figure(figsize=(20,20))
io.imshow(img)
plt.show()

# %%
np.log(2)
# Out:
# 0.6931471805599453
