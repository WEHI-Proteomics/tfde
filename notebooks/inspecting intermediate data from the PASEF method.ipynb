# %%
import sqlite3
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import glob, os
from pyteomics import mgf

# %%
ms1_deduped_df = pd.read_pickle('/Users/darylwilding-mcbride/Downloads/ms1_deduped_df.pkl')

# %%
ms1_deduped_df
# Out:
#         monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex  \
# 0       monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71168   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71244   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71243   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71242   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71241   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71240   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71239   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71238   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71237   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71236   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71235   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71234   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71233   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71232   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71231   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71230   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71229   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71228   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71227   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71226   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71225   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71224   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71223   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71222   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71245   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71246   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71247   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71260   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 71270   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# ...                   ...     ...              ...        ...        ...
# 35588   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35587   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35586   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35608   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35610   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35634   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35623   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35633   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35632   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35631   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35630   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35629   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35628   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35627   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35626   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35625   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35624   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35622   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35611   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35621   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35620   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35619   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35618   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35617   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35616   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35615   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35614   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35613   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 35612   monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
# 106854  monoisotopic_mass  charge  monoisotopic_mz  intensity  scan_apex
#
#         scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames  \
# 0       scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71168   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71244   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71243   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71242   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71241   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71240   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71239   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71238   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71237   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71236   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71235   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71234   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71233   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71232   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71231   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71230   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71229   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71228   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71227   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71226   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71225   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71224   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71223   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71222   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71245   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71246   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71247   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71260   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 71270   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# ...                ...      ...           ...           ...         ...
# 35588   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35587   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35586   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35608   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35610   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35634   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35623   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35633   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35632   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35631   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35630   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35629   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35628   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35627   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35626   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35625   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35624   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35622   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35611   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35621   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35620   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35619   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35618   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35617   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35616   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35615   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35614   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35613   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 35612   scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
# 106854  scan_curve_fit  rt_apex  rt_curve_fit  precursor_id  ms2_frames
#
#         duplicates  feature_id
# 0       duplicates           1
# 71168   duplicates           2
# 71244   duplicates           3
# 71243   duplicates           4
# 71242   duplicates           5
# 71241   duplicates           6
# 71240   duplicates           7
# 71239   duplicates           8
# 71238   duplicates           9
# 71237   duplicates          10
# 71236   duplicates          11
# 71235   duplicates          12
# 71234   duplicates          13
# 71233   duplicates          14
# 71232   duplicates          15
# 71231   duplicates          16
# 71230   duplicates          17
# 71229   duplicates          18
# 71228   duplicates          19
# 71227   duplicates          20
# 71226   duplicates          21
# 71225   duplicates          22
# 71224   duplicates          23
# 71223   duplicates          24
# 71222   duplicates          25
# 71245   duplicates          26
# 71246   duplicates          27
# 71247   duplicates          28
# 71260   duplicates          29
# 71270   duplicates          30
# ...            ...         ...
# 35588   duplicates      106826
# 35587   duplicates      106827
# 35586   duplicates      106828
# 35608   duplicates      106829
# 35610   duplicates      106830
# 35634   duplicates      106831
# 35623   duplicates      106832
# 35633   duplicates      106833
# 35632   duplicates      106834
# 35631   duplicates      106835
# 35630   duplicates      106836
# 35629   duplicates      106837
# 35628   duplicates      106838
# 35627   duplicates      106839
# 35626   duplicates      106840
# 35625   duplicates      106841
# 35624   duplicates      106842
# 35622   duplicates      106843
# 35611   duplicates      106844
# 35621   duplicates      106845
# 35620   duplicates      106846
# 35619   duplicates      106847
# 35618   duplicates      106848
# 35617   duplicates      106849
# 35616   duplicates      106850
# 35615   duplicates      106851
# 35614   duplicates      106852
# 35613   duplicates      106853
# 35612   duplicates      106854
# 106854  duplicates      106855
#
# [106855 rows x 12 columns]
