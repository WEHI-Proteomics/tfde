# %%
import pandas as pd
import sqlite3
import numpy as np
import matplotlib.pyplot as plt

# %%
mscypher_filename = "/home/ubuntu/UPS2_allion/MSCypher.txt"
mscypher_df = pd.read_table(mscypher_filename, sep="\t", dtype="str", engine='python')
feature_id=23
DB_NAME = "/home/ubuntu/UPS2_allion/UPS2_allion-features-1-1097.sqlite"

# %%
# convert the numeric fields and sort the features by their score
mscypher_df = mscypher_df.apply(pd.to_numeric, errors='ignore').sort_values(by=['FeatureNum','DiggerPepScore'], ascending=False)

# %%
# remove feature-duplicates from the MSC output, keeping the highest score
mscypher_df.drop_duplicates(subset=['FeatureNum'], keep='first', inplace=True)

# %%
mscypher_df.head()
# Out:
#        QueryNum  Target  Rank  NumPrecMatches  PepIDConsensus  PepPIF  MS2PIF  \
# 15158     15031  Target     1               0              30     0.0     0.0
# 5484       5420  Target     1               0              30     0.0     0.0
# 17443     17301  Target     1               0              30     0.0     0.0
# 16605     16465  Target     1               0              30     0.0     0.0
# 16592     16452  Target     1               0              30     0.0     0.0
#
#        NumScoringFragIonMatches  NumScoringFragIonPeaks  PercentSimilarity  \
# 15158                         0                       0               -1.0
# 5484                          0                       0               -1.0
# 17443                         0                       0               -1.0
# 16605                         0                       0               -1.0
# 16592                         0                       0               -1.0
#
#        ...  EndPos PreRes PostRes EnzymeSpecificity ProteinLength AccNums  \
# 15158  ...     nan    nan     nan               nan           nan     nan
# 5484   ...     nan    nan     nan               nan           nan     nan
# 17443  ...     nan    nan     nan               nan           nan     nan
# 16605  ...     nan    nan     nan               nan           nan     nan
# 16592  ...     nan    nan     nan               nan           nan     nan
#
#       FastaEntryNum  UniqueID  deltaCn XCorr
# 15158           nan     21019     -1.0   0.0
# 5484            nan     21018     -1.0   0.0
# 17443           nan     21017     -1.0   0.0
# 16605           nan     21016     -1.0   0.0
# 16592           nan     21015     -1.0   0.0
#
# [5 rows x 148 columns]

# %%
len(mscypher_df)
# Out:
# 19617

# %%
mscypher_df.columns.tolist()
# Out:
# ['QueryNum',
#  'Target',
#  'Rank',
#  'NumPrecMatches',
#  'PepIDConsensus',
#  'PepPIF',
#  'MS2PIF',
#  'NumScoringFragIonMatches',
#  'NumScoringFragIonPeaks',
#  'PercentSimilarity',
#  'PepSeq',
#  'deNovoSeq',
#  'rnkScr',
#  'pnvScr',
#  'EludePepSeq',
#  'VMLScore',
#  'Mods',
#  'NumMods',
#  'NumPhosphos',
#  'PhosphoMods',
#  'DiggerPepScore',
#  'DiggerPepHomologyScore',
#  'PercolatorQValue',
#  'PercolatorPEP',
#  'FeatureIntensityAUC',
#  'ObsRtMS2',
#  'ObsRtApex',
#  'PredRt',
#  'MZ',
#  'Charge',
#  'ExpMassDa',
#  'PepMassDa',
#  'DeltaMassDa',
#  'DeltaMassPPM',
#  'C13',
#  'NumDataPoints',
#  'NumScans',
#  'NumIsotopePeaks',
#  'FileName',
#  'MS2Scan',
#  'RMSErrorPPM',
#  'RMSErrorNumMatches',
#  'TIC',
#  'CompBondCleavage',
#  'DeltaScore',
#  'DeltaRt',
#  'ChimericStatus',
#  'FeatureNum',
#  'MissedCleavages',
#  'RPMS',
#  'SVMScore',
#  'SVMResult',
#  'SVMSig',
#  'RFFeatureScore',
#  'RFPSMScore',
#  'ModPepID',
#  'Rawfilename',
#  'RFRank',
#  'RFFeatureFDR',
#  'RFPsmFDR',
#  'TargetVotes',
#  'DecoyVotes',
#  'RFPrediction',
#  'MAErrorPPM',
#  'AltDeltaScore',
#  'FragMZ',
#  'FragInt',
#  'FragError',
#  'FragIonTypes',
#  'FragPos',
#  'FragCharge',
#  'a',
#  'b',
#  'b-18',
#  'b-17',
#  'b++',
#  'b++-18',
#  'b++-17',
#  'y',
#  'y-18',
#  'y-17',
#  'y++',
#  'y++-18',
#  'y++-17',
#  'imm',
#  'YB',
#  'YA',
#  'c',
#  'c++',
#  'z+1',
#  'z+1++',
#  'z+2',
#  'z+2++',
#  'Intensity a',
#  'Intensity b',
#  'Intensity b-18',
#  'Intensity b-17',
#  'Intensity b++',
#  'Intensity b++-18',
#  'Intensity b++-17',
#  'Intensity y',
#  'Intensity y-18',
#  'Intensity y-17',
#  'Intensity y++',
#  'Intensity y++-18',
#  'Intensity y++-17',
#  'Intensity imm',
#  'Intensity YB',
#  'Intensity YA',
#  'Intensity c',
#  'Intensity c++',
#  'Intensity z+1',
#  'Intensity z+1++',
#  'Intensity z+2',
#  'Intensity z+2++',
#  'Count a',
#  'Count b',
#  'Count b-18',
#  'Count b-17',
#  'Count b++',
#  'Count b++-18',
#  'Count b++-17',
#  'Count y',
#  'Count y-18',
#  'Count y-17',
#  'Count y++',
#  'Count y++-18',
#  'Count y++-17',
#  'Count imm',
#  'Count YB',
#  'Count YA',
#  'Count c',
#  'Count c++',
#  'Count z+1',
#  'Count z+1++',
#  'Count z+2',
#  'Count z+2++',
#  'StartPos',
#  'EndPos',
#  'PreRes',
#  'PostRes',
#  'EnzymeSpecificity',
#  'ProteinLength',
#  'AccNums',
#  'FastaEntryNum',
#  'UniqueID',
#  'deltaCn',
#  'XCorr']

# %%
msc_subset_df = mscypher_df[["DiggerPepScore", "FeatureNum", "FragMZ", "FragInt", "FragError", "FragIonTypes", "FragPos", "FragCharge", "DeltaMassDa", "DeltaMassPPM"]].copy()

# %%
msc_subset_df.head()
# Out:
#        DiggerPepScore  FeatureNum    FragMZ   FragInt FragError FragIonTypes  \
# 15158             0.0       21928  0.000000  0.000000  0.000000          x;x
# 5484              0.0       21927  0.000000  0.000000  0.000000          x;x
# 17443             0.0       21926  0.000000  0.000000  0.000000          x;x
# 16605             0.0       21925  0.000000  0.000000  0.000000          x;x
# 16592             0.0       21924  0.000000  0.000000  0.000000          x;x
#
#       FragPos FragCharge  DeltaMassDa  DeltaMassPPM
# 15158       0          0          0.0           0.0
# 5484        0          0          0.0           0.0
# 17443       0          0          0.0           0.0
# 16605       0          0          0.0           0.0
# 16592       0          0          0.0           0.0

# %%
msc_subset_df[msc_subset_df.FeatureNum==feature_id]
# Out:
#       DiggerPepScore  FeatureNum    FragMZ   FragInt FragError FragIonTypes  \
# 9849             0.0          23  0.000000  0.000000  0.000000          x;x
#
#      FragPos FragCharge  DeltaMassDa  DeltaMassPPM
# 9849       0          0          0.0           0.0

# %%
db_conn = sqlite3.connect(DB_NAME)
ms2_peaks_df = pd.read_sql_query("select feature_id,peak_id,centroid_mz,intensity from deconvoluted_ions where feature_id={}".format(feature_id), db_conn)
db_conn.close()

# %%
ms2_peaks_df.head()
# Out:
#    feature_id  peak_id  centroid_mz  intensity
# 0          23      166      201.122     182097
# 1          23      798      229.117      34762
# 2          23    11827      229.119      20207
# 3          23    13963      234.150      18504
# 4          23      275      235.107     112724

# %%
msc_fragments_df = pd.DataFrame([], columns=['FragMZ', 'FragInt', 'FragError', 'FragIonTypes', 'FragPos', 'FragCharge'])

# %%
msc_fragments_df
# Out:
# Empty DataFrame
# Columns: [FragMZ, FragInt, FragError, FragIonTypes, FragPos, FragCharge]
# Index: []

# %%
# break out the fragments reported by MSC for this feature
msc_fragments = msc_subset_df[msc_subset_df.FeatureNum==feature_id].iloc[0]
msc_fragments
# Out:
# DiggerPepScore           0
# FeatureNum              23
# FragMZ            0.000000
# FragInt           0.000000
# FragError         0.000000
# FragIonTypes           x;x
# FragPos                  0
# FragCharge               0
# DeltaMassDa              0
# DeltaMassPPM             0
# Name: 9849, dtype: object

# %%
FragMZ = list(map(float, msc_fragments.FragMZ.split(';')))
FragInt = list(map(float, msc_fragments.FragInt.split(';')))
FragError = list(map(float, msc_fragments.FragError.split(';')))
FragIonTypes = list(map(str, msc_fragments.FragIonTypes.split(';')))
FragPos = list(map(int, msc_fragments.FragPos.split(';')))
FragCharge = list(map(int, msc_fragments.FragCharge.split(';')))

# %%
msc_fragments_df = pd.DataFrame(list(zip(FragMZ, FragInt, FragError, FragIonTypes, FragPos, FragCharge)), columns=['FragMZ', 'FragInt', 'FragError', 'FragIonTypes', 'FragPos', 'FragCharge'])

# %%
msc_fragments_df
# Out:
#    FragMZ  FragInt  FragError FragIonTypes  FragPos  FragCharge
# 0     0.0      0.0        0.0            x        0           0

# %%
# round the join column to match the ms2 peaks with the fragments reported by MSC
msc_fragments_df["FragMZ_round"] = msc_fragments_df.FragMZ.round(3)
ms2_peaks_df["centroid_mz_round"] = ms2_peaks_df.centroid_mz.round(3)

# %%
# match up the ms2 peaks with the fragments reported by MSC
ms2_peaks_msc_fragments_df = pd.merge(ms2_peaks_df, msc_fragments_df, how='left', left_on=['centroid_mz_round'], right_on=['FragMZ_round'])

# %%
ms2_peaks_msc_fragments_df
# Out:
#       feature_id  peak_id  centroid_mz  intensity  centroid_mz_round  FragMZ  \
# 0             23        1      588.361    8997131            588.361     NaN
# 1             23        2      861.007   10594937            861.007     NaN
# 2             23        3      861.508   10319433            861.508     NaN
# 3             23        4      775.952    8247937            775.952     NaN
# 4             23        5      776.454    7359559            776.454     NaN
# 5             23        6      588.862    6130181            588.862     NaN
# 6             23        7      641.379    5337905            641.379     NaN
# 7             23        8      862.008    5489020            862.008     NaN
# 8             23        9      641.045    4903578            641.045     NaN
# 9             23       10      641.713    3218387            641.713     NaN
# 10            23       11      776.954    3477017            776.954     NaN
# 11            23       12      912.030    3420245            912.030     NaN
# 12            23       13     1175.716    3680533           1175.716     NaN
# 13            23       14      911.528    3242190            911.528     NaN
# 14            23       15      718.437    2980800            718.437     NaN
# 15            23       16      608.356    2622281            608.356     NaN
# 16            23       17      718.939    2553661            718.939     NaN
# 17            23       18      608.021    2525223            608.021     NaN
# 18            23       19      343.233    1894881            343.233     NaN
# 19            23       20      644.903    2526658            644.903     NaN
# 20            23       21      589.364    2362835            589.364     NaN
# 21            23       22      645.404    1871002            645.404     NaN
# 22            23       23     1176.718    2461137           1176.718     NaN
# 23            23       24      771.497    2021376            771.497     NaN
# 24            23       26      433.207    1643456            433.207     NaN
# 25            23       27      635.375    1909527            635.375     NaN
# 26            23       28      546.291    1645687            546.291     NaN
# 27            23       29      862.508    2033980            862.508     NaN
# 28            23       30      635.040    1763284            635.040     NaN
# 29            23       31      912.531    1895381            912.531     NaN
# ...          ...      ...          ...        ...                ...     ...
# 9327          23    25320     1395.353        105           1395.353     NaN
# 9328          23    25322      608.144       9277            608.144     NaN
# 9329          23    25323      458.023       1481            458.023     NaN
# 9330          23    25325      242.565        105            242.565     NaN
# 9331          23    25326      289.735        105            289.735     NaN
# 9332          23    25327      386.530        105            386.530     NaN
# 9333          23    25336      345.037        396            345.037     NaN
# 9334          23    25340      316.517        105            316.517     NaN
# 9335          23    25344      203.036        105            203.036     NaN
# 9336          23    25355      273.099        105            273.099     NaN
# 9337          23    25357      406.337        230            406.337     NaN
# 9338          23    25370     1083.111        105           1083.111     NaN
# 9339          23    25371     1059.152        240           1059.152     NaN
# 9340          23    25373      283.632        105            283.632     NaN
# 9341          23    25379      978.607        755            978.607     NaN
# 9342          23    25389      405.500       1072            405.500     NaN
# 9343          23    25391     1138.785        816           1138.785     NaN
# 9344          23    25395      375.368        100            375.368     NaN
# 9345          23    25396     1742.915        100           1742.915     NaN
# 9346          23    25397      404.580        100            404.580     NaN
# 9347          23    25398     1406.835        255           1406.835     NaN
# 9348          23    25402      259.788        100            259.788     NaN
# 9349          23    25403      372.829       4141            372.829     NaN
# 9350          23    25406      235.779        100            235.779     NaN
# 9351          23    25409     1488.628        100           1488.628     NaN
# 9352          23    25425     1476.668        100           1476.668     NaN
# 9353          23    25434      957.853       1566            957.853     NaN
# 9354          23    25435      276.324        100            276.324     NaN
# 9355          23    25439     1431.346        100           1431.346     NaN
# 9356          23    25443      533.150       2474            533.150     NaN
#
#       FragInt  FragError FragIonTypes  FragPos  FragCharge  FragMZ_round
# 0         NaN        NaN          NaN      NaN         NaN           NaN
# 1         NaN        NaN          NaN      NaN         NaN           NaN
# 2         NaN        NaN          NaN      NaN         NaN           NaN
# 3         NaN        NaN          NaN      NaN         NaN           NaN
# 4         NaN        NaN          NaN      NaN         NaN           NaN
# 5         NaN        NaN          NaN      NaN         NaN           NaN
# 6         NaN        NaN          NaN      NaN         NaN           NaN
# 7         NaN        NaN          NaN      NaN         NaN           NaN
# 8         NaN        NaN          NaN      NaN         NaN           NaN
# 9         NaN        NaN          NaN      NaN         NaN           NaN
# 10        NaN        NaN          NaN      NaN         NaN           NaN
# 11        NaN        NaN          NaN      NaN         NaN           NaN
# 12        NaN        NaN          NaN      NaN         NaN           NaN
# 13        NaN        NaN          NaN      NaN         NaN           NaN
# 14        NaN        NaN          NaN      NaN         NaN           NaN
# 15        NaN        NaN          NaN      NaN         NaN           NaN
# 16        NaN        NaN          NaN      NaN         NaN           NaN
# 17        NaN        NaN          NaN      NaN         NaN           NaN
# 18        NaN        NaN          NaN      NaN         NaN           NaN
# 19        NaN        NaN          NaN      NaN         NaN           NaN
# 20        NaN        NaN          NaN      NaN         NaN           NaN
# 21        NaN        NaN          NaN      NaN         NaN           NaN
# 22        NaN        NaN          NaN      NaN         NaN           NaN
# 23        NaN        NaN          NaN      NaN         NaN           NaN
# 24        NaN        NaN          NaN      NaN         NaN           NaN
# 25        NaN        NaN          NaN      NaN         NaN           NaN
# 26        NaN        NaN          NaN      NaN         NaN           NaN
# 27        NaN        NaN          NaN      NaN         NaN           NaN
# 28        NaN        NaN          NaN      NaN         NaN           NaN
# 29        NaN        NaN          NaN      NaN         NaN           NaN
# ...       ...        ...          ...      ...         ...           ...
# 9327      NaN        NaN          NaN      NaN         NaN           NaN
# 9328      NaN        NaN          NaN      NaN         NaN           NaN
# 9329      NaN        NaN          NaN      NaN         NaN           NaN
# 9330      NaN        NaN          NaN      NaN         NaN           NaN
# 9331      NaN        NaN          NaN      NaN         NaN           NaN
# 9332      NaN        NaN          NaN      NaN         NaN           NaN
# 9333      NaN        NaN          NaN      NaN         NaN           NaN
# 9334      NaN        NaN          NaN      NaN         NaN           NaN
# 9335      NaN        NaN          NaN      NaN         NaN           NaN
# 9336      NaN        NaN          NaN      NaN         NaN           NaN
# 9337      NaN        NaN          NaN      NaN         NaN           NaN
# 9338      NaN        NaN          NaN      NaN         NaN           NaN
# 9339      NaN        NaN          NaN      NaN         NaN           NaN
# 9340      NaN        NaN          NaN      NaN         NaN           NaN
# 9341      NaN        NaN          NaN      NaN         NaN           NaN
# 9342      NaN        NaN          NaN      NaN         NaN           NaN
# 9343      NaN        NaN          NaN      NaN         NaN           NaN
# 9344      NaN        NaN          NaN      NaN         NaN           NaN
# 9345      NaN        NaN          NaN      NaN         NaN           NaN
# 9346      NaN        NaN          NaN      NaN         NaN           NaN
# 9347      NaN        NaN          NaN      NaN         NaN           NaN
# 9348      NaN        NaN          NaN      NaN         NaN           NaN
# 9349      NaN        NaN          NaN      NaN         NaN           NaN
# 9350      NaN        NaN          NaN      NaN         NaN           NaN
# 9351      NaN        NaN          NaN      NaN         NaN           NaN
# 9352      NaN        NaN          NaN      NaN         NaN           NaN
# 9353      NaN        NaN          NaN      NaN         NaN           NaN
# 9354      NaN        NaN          NaN      NaN         NaN           NaN
# 9355      NaN        NaN          NaN      NaN         NaN           NaN
# 9356      NaN        NaN          NaN      NaN         NaN           NaN
#
# [9357 rows x 12 columns]

# %%
ms2_peaks_msc_fragments_df[ms2_peaks_msc_fragments_df.FragMZ.notnull()]
# Out:
# Empty DataFrame
# Columns: [feature_id, peak_id, centroid_mz, intensity, centroid_mz_round, FragMZ, FragInt, FragError, FragIonTypes, FragPos, FragCharge, FragMZ_round]
# Index: []

# %%
db_conn = sqlite3.connect(DB_NAME)
feature_list_df = pd.read_sql_query("select * from feature_list", db_conn)
db_conn.close()

# %%
feature_list_df.head()
# Out:
#    feature_id  charge_state  monoisotopic_mass  retention_time_secs  \
# 0           1             2        1066.606152                590.4
# 1           2             3        1928.009933                535.6
# 2           3             3        2044.113664               1023.2
# 3           4             2        1741.892439                720.6
# 4           5             3        1927.994175                536.2
#
#    isotope_count  cluster_mz_centroid  cluster_summed_intensity  \
# 0              6           534.310352                1985980902
# 1              7           643.677254                2425291014
# 2              7           682.378497                2881543763
# 3              6           871.953496                1248224845
# 4              8           643.672001                 461668922
#
#    minimum_error  minimum_error_sulphur
# 0   1.647301e-01                      0
# 1   7.140533e-06                      0
# 2   1.953337e-07                      2
# 3   9.673931e-03                      2
# 4   1.976963e-05                      0

# %%
# isolate the feature-level attributes reported by MSC
msc_feature_df = msc_subset_df[["FeatureNum","DiggerPepScore","DeltaMassDa","DeltaMassPPM"]]
msc_feature_df.head()
# Out:
#        FeatureNum  DiggerPepScore  DeltaMassDa  DeltaMassPPM
# 15158       21928             0.0          0.0           0.0
# 5484        21927             0.0          0.0           0.0
# 17443       21926             0.0          0.0           0.0
# 16605       21925             0.0          0.0           0.0
# 16592       21924             0.0          0.0           0.0

# %%
# annotate the features with the attributes reported by MSC.
# msc_DiggerPepScore of zero or more is what MSC reported. NaN means MSC didn't report the feature at all
feature_list_msc_df = pd.merge(feature_list_df, msc_feature_df, how='left', left_on=['feature_id'], right_on=['FeatureNum'])
feature_list_msc_df.drop(['FeatureNum'], inplace=True, axis=1)
feature_list_msc_df.rename(columns={'DiggerPepScore': 'msc_DiggerPepScore', 'DeltaMassDa': 'msc_DeltaMassDa', 'DeltaMassPPM': 'msc_DeltaMassPPM'}, inplace=True)

# %%
feature_list_msc_df.head()
# Out:
#    feature_id  charge_state  monoisotopic_mass  retention_time_secs  \
# 0           1             2        1066.606152                590.4
# 1           2             3        1928.009933                535.6
# 2           3             3        2044.113664               1023.2
# 3           4             2        1741.892439                720.6
# 4           5             3        1927.994175                536.2
#
#    isotope_count  cluster_mz_centroid  cluster_summed_intensity  \
# 0              6           534.310352                1985980902
# 1              7           643.677254                2425291014
# 2              7           682.378497                2881543763
# 3              6           871.953496                1248224845
# 4              8           643.672001                 461668922
#
#    minimum_error  minimum_error_sulphur  msc_DiggerPepScore  msc_DeltaMassDa  \
# 0   1.647301e-01                      0               0.000         0.000000
# 1   7.140533e-06                      0              29.583         0.009592
# 2   1.953337e-07                      2                 NaN              NaN
# 3   9.673931e-03                      2             320.189        -0.007459
# 4   1.976963e-05                      0               0.000         0.000000
#
#    msc_DeltaMassPPM
# 0             0.000
# 1             4.975
# 2               NaN
# 3            -4.282
# 4             0.000

# %%
feature_list_msc_df[feature_list_msc_df.msc_DiggerPepScore >= 0].head()
# Out:
#    feature_id  charge_state  monoisotopic_mass  retention_time_secs  \
# 0           1             2        1066.606152                590.4
# 1           2             3        1928.009933                535.6
# 3           4             2        1741.892439                720.6
# 4           5             3        1927.994175                536.2
# 9          10             2         986.560834                790.0
#
#    isotope_count  cluster_mz_centroid  cluster_summed_intensity  \
# 0              6           534.310352                1985980902
# 1              7           643.677254                2425291014
# 3              6           871.953496                1248224845
# 4              8           643.672001                 461668922
# 9              6           494.287693                1855507701
#
#    minimum_error  minimum_error_sulphur  msc_DiggerPepScore  msc_DeltaMassDa  \
# 0       0.164730                      0               0.000         0.000000
# 1       0.000007                      0              29.583         0.009592
# 3       0.009674                      2             320.189        -0.007459
# 4       0.000020                      0               0.000         0.000000
# 9       0.020531                      0              38.209        -0.003978
#
#    msc_DeltaMassPPM
# 0             0.000
# 1             4.975
# 3            -4.282
# 4             0.000
# 9            -4.032
